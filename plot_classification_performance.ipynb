# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
def plot_auc(ax, m3_m2_list, file_pattern, label):
    AUCs = []
    for m3, m2 in m3_m2_list:
        df = pd.read_csv(file_pattern.format(m3=m3, m2=m2))
        AUCs.append(df['AUC'])
    m3_m2_list = [f'{m3}/{m2}' for m3, m2 in m3_m2_list]
    ax.plot(m3_m2_list, AUCs, marker='o', label=label)

# %% [markdown]
# # DM-CPV

# %%
m3_m2_list = ['420/280', '500/275', '500/300', '520/325']

fig, ax = plt.subplots(figsize=(5, 4))

plot_auc(ax, m3_m2_list, './classification_performance/gghhh_bsm_{}/gghhh-4pT40_4b-test-DenseNN_abs_pairing.csv', 'Dense-NN w/ $|m - m_h|$')
plot_auc(ax, m3_m2_list, './classification_performance/gghhh_bsm_{}/gghhh-4pT40_4b-test-DenseNN_chi2_pairing.csv', 'Dense-NN w/ $(m - m_h)^2$')
plot_auc(ax, m3_m2_list, './classification_performance/gghhh_bsm_{}/gghhh-4pT40_4b-test-DenseNN_4b_SPANet_pairing.csv', 'Dense-NN w/ SPANet')
plot_auc(ax, m3_m2_list, './classification_performance/gghhh_bsm_{}/gghhh-4pT40_4b-test-SPANet_classifier.csv', 'SPANet classifier')

ax.set_title(f'$4b$ datasets')
ax.set_xlabel('$m_{h_3}/m_{h_2}$ [GeV]')
ax.set_ylabel('AUC')
ax.legend(frameon=False, loc='center right')

plt.savefig('./figures/classification_performance-4b_datasets.pdf', dpi=300, facecolor='White', bbox_inches='tight')
plt.show()

# %%
m3_m2_list = ['420/280', '500/275', '500/300', '520/325']

fig, ax = plt.subplots(figsize=(5, 4))

plot_auc(ax, m3_m2_list, './classification_performance/gghhh_bsm_{}/gghhh-4pT40_6b-DenseNN_abs_pairing.csv', 'Dense-NN w/ $|m - m_h|$')
plot_auc(ax, m3_m2_list, './classification_performance/gghhh_bsm_{}/gghhh-4pT40_6b-DenseNN_chi2_pairing.csv', 'Dense-NN w/ $(m - m_h)^2$')
plot_auc(ax, m3_m2_list, './classification_performance/gghhh_bsm_{}/gghhh-4pT40_6b-DenseNN_4b_SPANet_pairing.csv', 'Dense-NN w/ SPANet')
plot_auc(ax, m3_m2_list, './classification_performance/gghhh_bsm_{}/gghhh-4pT40_6b-1-SPANet_classifier.csv', 'SPANet classifier')

ax.set_title(f'$6b$ datasets')
ax.set_xlabel('$m_{h_3}/m_{h_2}$ [GeV]')
ax.set_ylabel('AUC')
ax.legend(frameon=False, loc='center right')

plt.savefig('./figures/classification_performance-6b_datasets.pdf', dpi=300, facecolor='White', bbox_inches='tight')
plt.show()

# %% [markdown]
# # TRSM

# %% [markdown]
# ## 4 mass points mixed: 4b 250k sig + 1M bkg; 6b 12.5k sig + 50k bkg

# %%
m3_m2_list = [(420, 280), (500, 275), (500, 300), (520, 325)]

fig, ax = plt.subplots(figsize=(5, 4))

plot_auc(ax, m3_m2_list, './classification_performance/TRSM/TRSM_{m3}_{m2}/gghhh-4pT40_4b-test-DenseNN_abs_pairing.csv', 'Dense-NN w/ $|m - m_h|$')
plot_auc(ax, m3_m2_list, './classification_performance/TRSM/TRSM_{m3}_{m2}/gghhh-4pT40_4b-test-DenseNN_chi2_pairing.csv', 'Dense-NN w/ $(m - m_h)^2$')
plot_auc(ax, m3_m2_list, './classification_performance/TRSM/TRSM_{m3}_{m2}/gghhh-4pT40_4b-test-DenseNN_4b_SPANet_pairing.csv', 'Dense-NN w/ SPANet')
plot_auc(ax, m3_m2_list, './classification_performance/TRSM/TRSM_{m3}_{m2}/gghhh-4pT40_4b-test-SPANet_classifier.csv', 'SPANet classifier')

ax.set_title(f'$4b$ datasets')
ax.set_xlabel('$m_{h_3}/m_{h_2}$ [GeV]')
ax.set_ylabel('AUC')
ax.legend(frameon=False, loc='center right')

plt.savefig('./figures/classification_performance-TRSM-4b_datasets.pdf', dpi=300, facecolor='White', bbox_inches='tight')
plt.show()

fig, ax = plt.subplots(figsize=(5, 4))

plot_auc(ax, m3_m2_list, './classification_performance/TRSM/TRSM_{m3}_{m2}/gghhh-4pT40_6b-DenseNN_abs_pairing.csv', 'Dense-NN w/ $|m - m_h|$')
plot_auc(ax, m3_m2_list, './classification_performance/TRSM/TRSM_{m3}_{m2}/gghhh-4pT40_6b-DenseNN_chi2_pairing.csv', 'Dense-NN w/ $(m - m_h)^2$')
plot_auc(ax, m3_m2_list, './classification_performance/TRSM/TRSM_{m3}_{m2}/gghhh-4pT40_6b-DenseNN_4b_SPANet_pairing.csv', 'Dense-NN w/ SPANet')
plot_auc(ax, m3_m2_list, './classification_performance/TRSM/TRSM_{m3}_{m2}/gghhh-4pT40_6b-1-SPANet_classifier.csv', 'SPANet classifier')

ax.set_title(f'$6b$ datasets')
ax.set_xlabel('$m_{h_3}/m_{h_2}$ [GeV]')
ax.set_ylabel('AUC')
ax.legend(frameon=False, loc='center right')

plt.savefig('./figures/classification_performance-TRSM-6b_datasets.pdf', dpi=300, facecolor='White', bbox_inches='tight')
plt.show()

# %% [markdown]
# ## 4 mass points mixed: 4b 750k sig + 1M bkg; 6b 12.5k sig + 50k bkg

# %%
m3_m2_list = [(420, 280), (500, 275), (500, 300), (520, 325)]

fig, ax = plt.subplots(figsize=(5, 4))

plot_auc(ax, m3_m2_list, './classification_performance/TRSM/TRSM_{m3}_{m2}/gghhh-4pT40_4b-test-DenseNN_abs_pairing.csv', 'Dense-NN w/ $|m - m_h|$')
plot_auc(ax, m3_m2_list, './classification_performance/TRSM/TRSM_{m3}_{m2}/gghhh-4pT40_4b-test-DenseNN_chi2_pairing.csv', 'Dense-NN w/ $(m - m_h)^2$')
plot_auc(ax, m3_m2_list, './classification_performance/TRSM/TRSM_{m3}_{m2}/gghhh-4pT40_4b-test-DenseNN_4b_SPANet_pairing.csv', 'Dense-NN w/ SPANet')
plot_auc(ax, m3_m2_list, './classification_performance/TRSM/TRSM_{m3}_{m2}/gghhh-4pT40_4b-test-SPANet_classifier.csv', 'SPANet classifier')

ax.set_title(f'$4b$ datasets')
ax.set_xlabel('$m_{h_3}/m_{h_2}$ [GeV]')
ax.set_ylabel('AUC')
ax.legend(frameon=False, loc='center right')

plt.savefig('./figures/classification_performance-TRSM-4b_datasets-750k.pdf', dpi=300, facecolor='White', bbox_inches='tight')
plt.show()

fig, ax = plt.subplots(figsize=(5, 4))

plot_auc(ax, m3_m2_list, './classification_performance/TRSM/TRSM_{m3}_{m2}/gghhh-4pT40_6b-DenseNN_abs_pairing.csv', 'Dense-NN w/ $|m - m_h|$')
plot_auc(ax, m3_m2_list, './classification_performance/TRSM/TRSM_{m3}_{m2}/gghhh-4pT40_6b-DenseNN_chi2_pairing.csv', 'Dense-NN w/ $(m - m_h)^2$')
plot_auc(ax, m3_m2_list, './classification_performance/TRSM/TRSM_{m3}_{m2}/gghhh-4pT40_6b-DenseNN_4b_SPANet_pairing.csv', 'Dense-NN w/ SPANet')
plot_auc(ax, m3_m2_list, './classification_performance/TRSM/TRSM_{m3}_{m2}/gghhh-4pT40_6b-1-SPANet_classifier.csv', 'SPANet classifier')

ax.set_title(f'$6b$ datasets')
ax.set_xlabel('$m_{h_3}/m_{h_2}$ [GeV]')
ax.set_ylabel('AUC')
ax.legend(frameon=False, loc='center right')

plt.savefig('./figures/classification_performance-TRSM-6b_datasets-750k.pdf', dpi=300, facecolor='White', bbox_inches='tight')
plt.show()

# %% [markdown]
# ## 5 mass points mixed: 4b 250M sig + 1M bkg; 6b 10k sig + 50k bkg

# %%
m3_m2_list = [(420, 280), (500, 275), (500, 300), (520, 325), (500, 350)]

fig, ax = plt.subplots(figsize=(5, 4))

plot_auc(ax, m3_m2_list, './classification_performance/TRSM/TRSM_{m3}_{m2}/gghhh-4pT40_4b-test-DenseNN_abs_pairing.csv', 'Dense-NN w/ $|m - m_h|$')
plot_auc(ax, m3_m2_list, './classification_performance/TRSM/TRSM_{m3}_{m2}/gghhh-4pT40_4b-test-DenseNN_chi2_pairing.csv', 'Dense-NN w/ $(m - m_h)^2$')
plot_auc(ax, m3_m2_list, './classification_performance/TRSM/TRSM_{m3}_{m2}/gghhh-4pT40_4b-test-DenseNN_mix_5-4b_SPANet_pairing.csv', 'Dense-NN w/ SPANet')
plot_auc(ax, m3_m2_list, './classification_performance/TRSM/TRSM_{m3}_{m2}/gghhh-4pT40_4b-test-mix_5-SPANet_classifier.csv', 'SPANet classifier')

ax.set_title(f'$4b$ datasets')
ax.set_xlabel('$m_{h_3}/m_{h_2}$ [GeV]')
ax.set_ylabel('AUC')
ax.legend(frameon=False, loc='center right')

plt.savefig('./figures/classification_performance-TRSM-4b_datasets-mix_5-250k.pdf', dpi=300, facecolor='White', bbox_inches='tight')
plt.show()

fig, ax = plt.subplots(figsize=(5, 4))

plot_auc(ax, m3_m2_list, './classification_performance/TRSM/TRSM_{m3}_{m2}/gghhh-4pT40_6b-DenseNN_abs_pairing.csv', 'Dense-NN w/ $|m - m_h|$')
plot_auc(ax, m3_m2_list, './classification_performance/TRSM/TRSM_{m3}_{m2}/gghhh-4pT40_6b-DenseNN_chi2_pairing.csv', 'Dense-NN w/ $(m - m_h)^2$')
plot_auc(ax, m3_m2_list, './classification_performance/TRSM/TRSM_{m3}_{m2}/gghhh-4pT40_6b-DenseNN_mix_5-4b_SPANet_pairing.csv', 'Dense-NN w/ SPANet')
plot_auc(ax, m3_m2_list, './classification_performance/TRSM/TRSM_{m3}_{m2}/gghhh-4pT40_6b-1-mix_5-SPANet_classifier.csv', 'SPANet classifier')

ax.set_title(f'$6b$ datasets')
ax.set_xlabel('$m_{h_3}/m_{h_2}$ [GeV]')
ax.set_ylabel('AUC')
ax.legend(frameon=False, loc='center right')

plt.savefig('./figures/classification_performance-TRSM-6b_datasets-mix_5-250k.pdf', dpi=300, facecolor='White', bbox_inches='tight')
plt.show()

# %% [markdown]
# ## 5 mass points mixed: 4b 1M sig + 1M bkg; 6b 10k sig + 50k bkg

# %%
m3_m2_list = [(420, 280), (500, 275), (500, 300), (520, 325), (500, 350)]

fig, ax = plt.subplots(figsize=(5, 4))

plot_auc(ax, m3_m2_list, './classification_performance/TRSM/TRSM_{m3}_{m2}/gghhh-4pT40_4b-test-DenseNN_abs_pairing.csv', 'Dense-NN w/ $|m - m_h|$')
plot_auc(ax, m3_m2_list, './classification_performance/TRSM/TRSM_{m3}_{m2}/gghhh-4pT40_4b-test-DenseNN_chi2_pairing.csv', 'Dense-NN w/ $(m - m_h)^2$')
plot_auc(ax, m3_m2_list, './classification_performance/TRSM/TRSM_{m3}_{m2}/gghhh-4pT40_4b-test-DenseNN_4b_SPANet_pairing-mix_5-1M.csv', 'Dense-NN w/ SPANet')
plot_auc(ax, m3_m2_list, './classification_performance/TRSM/TRSM_{m3}_{m2}/gghhh-4pT40_4b-test-4b_SPANet_predict-mix_5-1M.csv', 'SPANet classifier')

ax.set_title(f'$4b$ datasets')
ax.set_xlabel('$m_{h_3}/m_{h_2}$ [GeV]')
ax.set_ylabel('AUC')
ax.legend(frameon=False, loc='center right')

plt.savefig('./figures/classification_performance-TRSM-4b_datasets-mix_5-1M.pdf', dpi=300, facecolor='White', bbox_inches='tight')
plt.show()

fig, ax = plt.subplots(figsize=(5, 4))

plot_auc(ax, m3_m2_list, './classification_performance/TRSM/TRSM_{m3}_{m2}/gghhh-4pT40_6b-test-DenseNN_abs_pairing.csv', 'Dense-NN w/ $|m - m_h|$')
plot_auc(ax, m3_m2_list, './classification_performance/TRSM/TRSM_{m3}_{m2}/gghhh-4pT40_6b-test-DenseNN_chi2_pairing.csv', 'Dense-NN w/ $(m - m_h)^2$')
plot_auc(ax, m3_m2_list, './classification_performance/TRSM/TRSM_{m3}_{m2}/gghhh-4pT40_6b-test-DenseNN_4b_SPANet_pairing-mix_5-1M.csv', 'Dense-NN w/ SPANet')
plot_auc(ax, m3_m2_list, './classification_performance/TRSM/TRSM_{m3}_{m2}/gghhh-4pT40_6b-test-4b_SPANet_predict-mix_5-1M.csv', 'SPANet classifier')

ax.set_title(f'$6b$ datasets')
ax.set_xlabel('$m_{h_3}/m_{h_2}$ [GeV]')
ax.set_ylabel('AUC')
ax.legend(frameon=False, loc='center right')

plt.savefig('./figures/classification_performance-TRSM-6b_datasets-mix_5-1M.pdf', dpi=300, facecolor='White', bbox_inches='tight')
plt.show()

# %%
m3_m2_list = [(420, 280), (500, 275), (500, 300), (520, 325), (500, 350)]

fig, ax = plt.subplots(figsize=(5, 4))

plot_auc(ax, m3_m2_list, './classification_performance/TRSM/TRSM_{m3}_{m2}/gghhh-4pT40_4b-test-DenseNN_chi2_pairing.csv', 'Dense-NN with $\chi^2$ pairing')
plot_auc(ax, m3_m2_list, './classification_performance/TRSM/TRSM_{m3}_{m2}/gghhh-4pT40_4b-test-DenseNN_abs_pairing.csv', 'Dense-NN with $|\chi|$ pairing')
plot_auc(ax, m3_m2_list, './classification_performance/TRSM/TRSM_{m3}_{m2}/gghhh-4pT40_4b-test-DenseNN_4b_SPANet_pairing-mix_5-1M.csv', 'Dense-NN with SPANet pairing')
plot_auc(ax, m3_m2_list, './classification_performance/TRSM/TRSM_{m3}_{m2}/gghhh-4pT40_4b-test-4b_SPANet_predict-mix_5-1M.csv', 'SPANet classifier')

ax.set_title(f'$4b$ datasets')
ax.set_xlabel('$m_{h_3}/m_{h_2}$ [GeV]')
ax.set_ylabel('AUC')
ax.legend(frameon=False, loc='center right')

plt.savefig('./figures/draft/classification_performance-TRSM-4b_datasets-mix_5-1M.pdf', dpi=300, facecolor='White', bbox_inches='tight')
plt.show()

fig, ax = plt.subplots(figsize=(5, 4))

plot_auc(ax, m3_m2_list, './classification_performance/TRSM/TRSM_{m3}_{m2}/gghhh-4pT40_6b-test-DenseNN_chi2_pairing.csv', 'Dense-NN with $\chi^2$ pairing')
plot_auc(ax, m3_m2_list, './classification_performance/TRSM/TRSM_{m3}_{m2}/gghhh-4pT40_6b-test-DenseNN_abs_pairing.csv', 'Dense-NN with $|\chi|$ pairing')
plot_auc(ax, m3_m2_list, './classification_performance/TRSM/TRSM_{m3}_{m2}/gghhh-4pT40_6b-test-DenseNN_4b_SPANet_pairing-mix_5-1M.csv', 'Dense-NN with SPANet pairing')
plot_auc(ax, m3_m2_list, './classification_performance/TRSM/TRSM_{m3}_{m2}/gghhh-4pT40_6b-test-4b_SPANet_predict-mix_5-1M.csv', 'SPANet classifier')

ax.set_title(f'$6b$ datasets')
ax.set_xlabel('$m_{h_3}/m_{h_2}$ [GeV]')
ax.set_ylabel('AUC')
ax.legend(frameon=False, bbox_to_anchor=(1.0, 0.77))

plt.savefig('./figures/poster/classification_performance-TRSM-6b_datasets-mix_5-1M.pdf', dpi=300, facecolor='White', bbox_inches='tight')
plt.show()

# %% [markdown]
# ## 5 mass points mixed: 4b 1M sig + 1M bkg; 6b 10k sig + 50k bkg, 24 nodes x 3

# %%
m3_m2_list = [(420, 280), (500, 275), (500, 300), (520, 325), (500, 350)]

fig, ax = plt.subplots(figsize=(5, 4))

plot_auc(ax, m3_m2_list, './classification_performance/TRSM/TRSM_{m3}_{m2}/gghhh-4pT40_4b-test-DenseNN_abs_pairing-24_nodes.csv', 'Dense-NN w/ $|m - m_h|$')
plot_auc(ax, m3_m2_list, './classification_performance/TRSM/TRSM_{m3}_{m2}/gghhh-4pT40_4b-test-DenseNN_chi2_pairing-24_nodes.csv', 'Dense-NN w/ $(m - m_h)^2$')
plot_auc(ax, m3_m2_list, './classification_performance/TRSM/TRSM_{m3}_{m2}/gghhh-4pT40_4b-test-DenseNN_4b_SPANet_pairing-mix_5-1M-24_nodes.csv', 'Dense-NN w/ SPANet')

plot_auc(ax, m3_m2_list, './classification_performance/TRSM/TRSM_{m3}_{m2}/gghhh-4pT40_4b-test-4b_SPANet_predict-mix_5-1M.csv', 'SPANet classifier')

ax.set_title(f'$4b$ datasets')
ax.set_xlabel('$m_{h_3}/m_{h_2}$ [GeV]')
ax.set_ylabel('AUC')
ax.legend(frameon=False, loc='center right')

# plt.savefig('./figures/classification_performance-TRSM-4b_datasets-mix_5-1M.pdf', dpi=300, facecolor='White', bbox_inches='tight')
plt.show()

fig, ax = plt.subplots(figsize=(5, 4))

plot_auc(ax, m3_m2_list, './classification_performance/TRSM/TRSM_{m3}_{m2}/gghhh-4pT40_6b-test-DenseNN_abs_pairing-24_nodes.csv', 'Dense-NN w/ $|m - m_h|$')
plot_auc(ax, m3_m2_list, './classification_performance/TRSM/TRSM_{m3}_{m2}/gghhh-4pT40_6b-test-DenseNN_chi2_pairing-24_nodes.csv', 'Dense-NN w/ $(m - m_h)^2$')
plot_auc(ax, m3_m2_list, './classification_performance/TRSM/TRSM_{m3}_{m2}/gghhh-4pT40_6b-test-DenseNN_4b_SPANet_pairing-mix_5-1M-24_nodes.csv', 'Dense-NN w/ SPANet')

plot_auc(ax, m3_m2_list, './classification_performance/TRSM/TRSM_{m3}_{m2}/gghhh-4pT40_6b-test-4b_SPANet_predict-mix_5-1M.csv', 'SPANet classifier')

ax.set_title(f'$6b$ datasets')
ax.set_xlabel('$m_{h_3}/m_{h_2}$ [GeV]')
ax.set_ylabel('AUC')
ax.legend(frameon=False, loc='center right')

# plt.savefig('./figures/classification_performance-TRSM-6b_datasets-mix_5-1M.pdf', dpi=300, facecolor='White', bbox_inches='tight')
plt.show()

# %% [markdown]
# ## 5 mass points mixed: 4b 150k sig + 150k bkg; 6b 10k sig + 50k bkg, 24 nodes x 3

# %%
m3_m2_list = [(420, 280), (500, 275), (500, 300), (520, 325), (500, 350)]

fig, ax = plt.subplots(figsize=(5, 4))

plot_auc(ax, m3_m2_list, './classification_performance/TRSM/TRSM_{m3}_{m2}/gghhh-4pT40_4b-test-DenseNN_abs_pairing-150k-24_nodes.csv', 'Dense-NN w/ $|m - m_h|$')
plot_auc(ax, m3_m2_list, './classification_performance/TRSM/TRSM_{m3}_{m2}/gghhh-4pT40_4b-test-DenseNN_chi2_pairing-150k-24_nodes.csv', 'Dense-NN w/ $(m - m_h)^2$')
plot_auc(ax, m3_m2_list, './classification_performance/TRSM/TRSM_{m3}_{m2}/gghhh-4pT40_4b-test-DenseNN_4b_SPANet_pairing-mix_5-1M-150k-24_nodes.csv', 'Dense-NN w/ SPANet')

plot_auc(ax, m3_m2_list, './classification_performance/TRSM/TRSM_{m3}_{m2}/gghhh-4pT40_4b-test-4b_SPANet_predict-mix_5-1M.csv', 'SPANet classifier')

ax.set_title(f'$4b$ datasets')
ax.set_xlabel('$m_{h_3}/m_{h_2}$ [GeV]')
ax.set_ylabel('AUC')
ax.legend(frameon=False, loc='center right')

plt.savefig('./figures/classification_performance-TRSM-4b_datasets-mix_5-150k-24_nodes.pdf', dpi=300, facecolor='White', bbox_inches='tight')
plt.show()

fig, ax = plt.subplots(figsize=(5, 4))

plot_auc(ax, m3_m2_list, './classification_performance/TRSM/TRSM_{m3}_{m2}/gghhh-4pT40_6b-test-DenseNN_abs_pairing-150k-24_nodes.csv', 'Dense-NN w/ $|m - m_h|$')
plot_auc(ax, m3_m2_list, './classification_performance/TRSM/TRSM_{m3}_{m2}/gghhh-4pT40_6b-test-DenseNN_chi2_pairing-150k-24_nodes.csv', 'Dense-NN w/ $(m - m_h)^2$')
plot_auc(ax, m3_m2_list, './classification_performance/TRSM/TRSM_{m3}_{m2}/gghhh-4pT40_6b-test-DenseNN_4b_SPANet_pairing-mix_5-1M-150k-24_nodes.csv', 'Dense-NN w/ SPANet')

plot_auc(ax, m3_m2_list, './classification_performance/TRSM/TRSM_{m3}_{m2}/gghhh-4pT40_6b-test-4b_SPANet_predict-mix_5-1M.csv', 'SPANet classifier')

ax.set_title(f'$6b$ datasets')
ax.set_xlabel('$m_{h_3}/m_{h_2}$ [GeV]')
ax.set_ylabel('AUC')
ax.legend(frameon=False, loc='center right')

plt.savefig('./figures/classification_performance-TRSM-6b_datasets-mix_5-150k-24_nodes.pdf', dpi=300, facecolor='White', bbox_inches='tight')
plt.show()
