# %%
import sys
import ROOT

import numpy as np
import pandas as pd

from tqdm import tqdm

sys.path.append('..')
import utils_HDF5 as utils

delphes_path = '/usr/local/Delphes-3.4.2'
ROOT.gROOT.ProcessLine(f'.include {delphes_path}/')
ROOT.gROOT.ProcessLine(f'.include {delphes_path}/external/')
ROOT.gInterpreter.Declare(f'#include "{delphes_path}/classes/DelphesClasses.h"')
ROOT.gSystem.Load(f'{delphes_path}/install/lib/libDelphes')

MAX_JETS = 15
# Out:
# Welcome to JupyROOT 6.20/08

# %%
def DeltaR(eta1, phi1, eta2, phi2):
    dEta = eta1 - eta2
    dPhi = np.abs(phi1 - phi2)

    dPhi = np.where(dPhi > np.pi, 2 * np.pi - dPhi, dPhi)

    dR = np.sqrt(dPhi**2 + dEta**2)
    return dR

# %%
def print_cutflow_table(counts):
    n_tot = counts['total']
    n_previous = counts['total']
    print(f"{'Cut':<26} {'n':8} {'efficiency':8} {'passing rate':8}")
    for key, value in counts.items():
        if key not in ['3 Higgs', '2 Higgs', '1 Higgs']:
            print(f'{key:<26} {value:>8} {value / n_previous:>8.2f} {value / n_tot:>8.2f}')
            n_previous = value
        else:
            print(f'{key:<26} {value:>8} {value / n_previous:>8.2f} {value / n_tot:>8.2f}')

# %%
def print_matching_table(total_event, matched_event, nj=(6, 8), jet_type='Nj'):

    start, end = nj

    event_type = [f'{jet_type}={nj}' for nj in range(start, end)]
    event_type.append(f'{jet_type}>={end}')
    event_type.append('Total')

    event_fraction = [total_event[nj] / total_event.sum() for nj in range(start, end)]
    event_fraction.append(total_event[end:].sum() / total_event.sum())
    event_fraction.append(total_event.sum() / total_event.sum())

    matching_rate = [matched_event[nj] / total_event[nj].sum() for nj in range(start, end)]
    matching_rate.append(matched_event[end:].sum() / total_event[end:].sum())
    matching_rate.append(matched_event.sum() / total_event.sum())

        
    result = {
              'Event type': event_type,
              'Event Fraction': event_fraction,
              'Matching Rate': matching_rate,
             }

    df = pd.DataFrame(result)
    print(df)

    df_style = df.style.format({
            'Event Fraction': '{:.3f}',
            'Matching Rate': '{:.3f}',
        })
    print(df_style.to_latex(column_format='c|cc'))

# %%
def select_event(root_path, nbj_min, start, end):
    counts = {
        'total': 0,
        '>= 6 jets': 0,
        '>= 4 jets with pT > 40 GeV': 0,
        '>= 4 b-jets': 0,
        '3 Higgs': 0,
        '2 Higgs': 0,
        '1 Higgs': 0,
    }

    total_event_bjet = np.zeros(MAX_JETS + 5)
    matched_event_bjet = np.zeros(MAX_JETS + 5)
    total_event_Njet = np.zeros(MAX_JETS + 5)
    matched_event_Njet = np.zeros(MAX_JETS + 5)

    f = ROOT.TFile(root_path)
    tree = f.Get("Delphes")

    for i in tqdm(range(start, end)):
        tree.GetEntry(i)

        # 夸克資料
        # b夸克 衰變前的編號
        quarks_id = []
        quarks_Eta = []
        quarks_Phi = []
        quarks_Jet = np.array([-1, -1, -1, -1, -1, -1])

        # 找出 3 個 final Higgs
        final_h_index = []
        for index, particle in enumerate(tree.Particle):
            if particle.PID == 25:
                h = index
                d1 = tree.Particle[h].D1
                while tree.Particle[d1].PID == 25:
                    h = d1
                    d1 = tree.Particle[h].D1
                final_h_index.append(h)

        final_h_index = list(set(final_h_index))

        # 找出 6 個 final b quark
        for h in final_h_index:
            # h > b b~
            b1 = tree.Particle[h].D1
            b2 = tree.Particle[h].D2

            # 找出 b 衰變前的編號
            d1 = tree.Particle[b1].D1
            while abs(tree.Particle[d1].PID) == 5:
                b1 = d1
                d1 = tree.Particle[b1].D1

            # 找出 b~ 衰變前的編號
            d2 = tree.Particle[b2].D1
            while abs(tree.Particle[d2].PID) == 5:
                b2 = d2
                d2 = tree.Particle[b2].D1

            quarks_id.extend([b1, b2])

        quarks_Eta.extend(tree.Particle[quark].Eta for quark in quarks_id)
        quarks_Phi.extend(tree.Particle[quark].Phi for quark in quarks_id)

        # 事件中的 jet 資料
        jet_PT = np.array([jet.PT for jet in tree.Jet])
        jet_Eta = np.array([jet.Eta for jet in tree.Jet])
        jet_Phi = np.array([jet.Phi for jet in tree.Jet])
        jet_Mass = np.array([jet.Mass for jet in tree.Jet])
        jet_BTag = np.array([jet.BTag for jet in tree.Jet])

        # Jet 資料
        # |eta| < 2.5 & PT > 20 GeV
        eta_pt_cut = np.array((np.abs(jet_Eta) < 2.5) & (jet_PT > 20))
        # |eta| < 2.5 & PT > 40 GeV
        eta_pt40_cut = np.array((np.abs(jet_Eta) < 2.5) & (jet_PT > 40))

        nj = eta_pt_cut.sum()

        counts['total'] += 1
        # 至少要 6 jet
        if nj < 6:
            continue
        counts['>= 6 jets'] += 1
        # 至少要 4 jet pT > 40 GeV
        if eta_pt40_cut.sum() < 4:
            continue
        counts['>= 4 jets with pT > 40 GeV'] += 1
        nbj = np.array(jet_BTag[eta_pt_cut][:MAX_JETS]).sum()
        # 在前 MAX_JETS jets 中，至少要 nbj_min 個 b-jet
        if nbj < nbj_min:
            continue
        counts['>= 4 b-jets'] += 1
        total_event_bjet[nbj] += 1
        total_event_Njet[nj] += 1

        # PT = np.array(jet_PT[eta_pt_cut])
        Eta = np.array(jet_Eta[eta_pt_cut])
        Phi = np.array(jet_Phi[eta_pt_cut])
        # Mass = np.array(jet_Mass[eta_pt_cut])
        # BTag = np.array(jet_BTag[eta_pt_cut])

        # 找出每個夸克配對的 jet
        # more_than_1_jet = False
        for quark in range(len(quarks_Jet)):
            dR = DeltaR(quarks_Eta[quark], quarks_Phi[quark], Eta, Phi)
            if dR.min() < 0.4:
                quarks_Jet[quark] = np.argmin(dR)


        quark_jet = quarks_Jet.reshape(1, 6)

        h1_mask = utils.get_particle_mask(quark_jet, [0, 1])
        h2_mask = utils.get_particle_mask(quark_jet, [2, 3])
        h3_mask = utils.get_particle_mask(quark_jet, [4, 5])

        nh = [h1_mask, h2_mask, h3_mask].count(True)

        if nh == 3:
            counts['3 Higgs'] += 1
            matched_event_bjet[nbj] += 1
            matched_event_Njet[nj] += 1
        elif nh == 2:
            counts['2 Higgs'] += 1
        elif nh == 1:
            counts['1 Higgs'] += 1
       
    print_cutflow_table(counts)
    print_matching_table(total_event_bjet, matched_event_bjet, (4, 6), 'Nbj')
    print_matching_table(total_event_Njet, matched_event_Njet, (6, 8), 'Nj')

# %%
def compute_cutflow_table(root_path, nbj_min=0):
    f = ROOT.TFile(root_path)
    nevent = f.Get("Delphes").GetEntries()
    print(f'Number of events: {nevent}')

    start = 0
    # end = nevent
    end = 10000

    select_event(root_path, nbj_min, start, end)

# %%
root_path = './MG5/gghhh_bsm/Events/run_01_decayed_1/tag_2_delphes_events.root'
nbj_min = 4

compute_cutflow_table(root_path, nbj_min=nbj_min)
# Out:
# Number of events: 100000
# 100%|██████████| 100000/100000 [09:22<00:00, 177.83it/s]
# Cut                        n        efficiency passing rate
# total                        100000     1.00     1.00
# >= 6 jets                     61454     0.61     0.61
# >= 4 jets with pT > 40 GeV    50341     0.82     0.50
# >= 4 b-jets                   32337     0.64     0.32
# 3 Higgs                        9944     0.31     0.10
# 2 Higgs                       11341     0.35     0.11
# 1 Higgs                        8941     0.28     0.09
#   Event type  Event Fraction  Matching Rate
# 0      Nbj=4        0.509107       0.186843
# 1      Nbj=5        0.368247       0.353796
# 2      Nbj=6        0.112626       0.669138
# 3      Nbj=7        0.009401       0.674342
# 4      Nbj=8        0.000618       0.650000
# 5     Nbj>=9        0.000000            NaN
# 6      Total        1.000000       0.307512
# \begin{tabular}{c|cc}
#  & Event type & Event Fraction & Matching Rate \\
# 0 & Nbj=4 & 0.509 & 0.187 \\
# 1 & Nbj=5 & 0.368 & 0.354 \\
# 2 & Nbj=6 & 0.113 & 0.669 \\
# 3 & Nbj=7 & 0.009 & 0.674 \\
# 4 & Nbj=8 & 0.001 & 0.650 \\
# 5 & Nbj>=9 & 0.000 & nan \\
# 6 & Total & 1.000 & 0.308 \\
# \end{tabular}
#
#   Event type  Event Fraction  Matching Rate
# 0       Nj=6        0.341126       0.218385
# 1       Nj=7        0.320469       0.321722
# 2      Nj>=8        0.338405       0.383898
# 3      Total        1.000000       0.307512
# \begin{tabular}{c|cc}
#  & Event type & Event Fraction & Matching Rate \\
# 0 & Nj=6 & 0.341 & 0.218 \\
# 1 & Nj=7 & 0.320 & 0.322 \\
# 2 & Nj>=8 & 0.338 & 0.384 \\
# 3 & Total & 1.000 & 0.308 \\
# \end{tabular}
# /tmp/ipykernel_2843966/2570250950.py:14: RuntimeWarning: invalid value encountered in scalar divide
#   matching_rate.append(matched_event[end:].sum() / total_event[end:].sum())

# %%
root_path = './MG5/pphhh_sm/Events/run_01_decayed_1/tag_1_delphes_events.root'
nbj_min = 4

compute_cutflow_table(root_path, nbj_min=nbj_min)
# Out:
# Number of events: 100000
# 100%|██████████| 100000/100000 [11:04<00:00, 150.42it/s]
# /tmp/ipykernel_2843966/2570250950.py:14: RuntimeWarning: invalid value encountered in scalar divide
#   matching_rate.append(matched_event[end:].sum() / total_event[end:].sum())
# Cut                        n        efficiency passing rate
# total                        100000     1.00     1.00
# >= 6 jets                     74878     0.75     0.75
# >= 4 jets with pT > 40 GeV    70399     0.94     0.70
# >= 4 b-jets                   48734     0.69     0.49
# 3 Higgs                       17599     0.36     0.18
# 2 Higgs                       18601     0.38     0.19
# 1 Higgs                       10759     0.22     0.11
#   Event type  Event Fraction  Matching Rate
# 0      Nbj=4        0.474966       0.227416
# 1      Nbj=5        0.377806       0.395449
# 2      Nbj=6        0.131818       0.701743
# 3      Nbj=7        0.013933       0.723122
# 4      Nbj=8        0.001354       0.742424
# 5      Nbj=9        0.000103       1.000000
# 6     Nbj=10        0.000021       1.000000
# 7    Nbj>=11        0.000000            NaN
# 8      Total        1.000000       0.361124
# \begin{tabular}{c|cc}
#  & Event type & Event Fraction & Matching Rate \\
# 0 & Nbj=4 & 0.475 & 0.227 \\
# 1 & Nbj=5 & 0.378 & 0.395 \\
# 2 & Nbj=6 & 0.132 & 0.702 \\
# 3 & Nbj=7 & 0.014 & 0.723 \\
# 4 & Nbj=8 & 0.001 & 0.742 \\
# 5 & Nbj=9 & 0.000 & 1.000 \\
# 6 & Nbj=10 & 0.000 & 1.000 \\
# 7 & Nbj>=11 & 0.000 & nan \\
# 8 & Total & 1.000 & 0.361 \\
# \end{tabular}
#
#   Event type  Event Fraction  Matching Rate
# 0       Nj=6        0.281754       0.226713
# 1       Nj=7        0.307137       0.352418
# 2      Nj>=8        0.411109       0.459745
# 3      Total        1.000000       0.361124
# \begin{tabular}{c|cc}
#  & Event type & Event Fraction & Matching Rate \\
# 0 & Nj=6 & 0.282 & 0.227 \\
# 1 & Nj=7 & 0.307 & 0.352 \\
# 2 & Nj>=8 & 0.411 & 0.460 \\
# 3 & Total & 1.000 & 0.361 \\
# \end{tabular}

# %%
root_path = '/home/public/3h_1500_1000.root'
nbj_min = 4

compute_cutflow_table(root_path, nbj_min=nbj_min)
# Out:
# Number of events: 100000
#   0%|          | 0/10000 [00:00<?, ?it/s]
# 100%|██████████| 10000/10000 [00:54<00:00, 183.18it/s]
# Cut                        n        efficiency passing rate
# total                         10000     1.00     1.00
# >= 6 jets                      7563     0.76     0.76
# >= 4 jets with pT > 40 GeV     7502     0.99     0.75
# >= 4 b-jets                    3628     0.48     0.36
# 3 Higgs                        1232     0.34     0.12
# 2 Higgs                        1692     0.47     0.17
# 1 Higgs                         599     0.17     0.06
#   Event type  Event Fraction  Matching Rate
# 0      Nbj=4        0.602536       0.259835
# 1      Nbj=5        0.315877       0.408377
# 2     Nbj>=6        0.081588       0.662162
# 3      Total        1.000000       0.339581
# \begin{tabular}{c|cc}
#  & Event type & Event Fraction & Matching Rate \\
# 0 & Nbj=4 & 0.603 & 0.260 \\
# 1 & Nbj=5 & 0.316 & 0.408 \\
# 2 & Nbj>=6 & 0.082 & 0.662 \\
# 3 & Total & 1.000 & 0.340 \\
# \end{tabular}
#
#   Event type  Event Fraction  Matching Rate
# 0       Nj=6        0.281974       0.188661
# 1       Nj=7        0.311191       0.340124
# 2      Nj>=8        0.406836       0.443767
# 3      Total        1.000000       0.339581
# \begin{tabular}{c|cc}
#  & Event type & Event Fraction & Matching Rate \\
# 0 & Nj=6 & 0.282 & 0.189 \\
# 1 & Nj=7 & 0.311 & 0.340 \\
# 2 & Nj>=8 & 0.407 & 0.444 \\
# 3 & Total & 1.000 & 0.340 \\
# \end{tabular}
# Warning in <TStreamerInfo::BuildCheck>:
#    The StreamerInfo of class Track read from file /home/public/3h_1500_1000.root
#    has the same version (=3) as the active class but a different checksum.
#    You should update the version to ClassDef(Track,4).
#    Do not try to write objects with the current class definition,
#    the files will not be readable.
#
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the in-memory layout version 3 of class 'Track' is missing from
# the on-file layout version 3:
#    float C; //
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the in-memory layout version 3 of class 'Track' is missing from
# the on-file layout version 3:
#    float Mass; //
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the in-memory layout version 3 of class 'Track' is missing from
# the on-file layout version 3:
#    float EtaOuter; //
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the in-memory layout version 3 of class 'Track' is missing from
# the on-file layout version 3:
#    float PhiOuter; //
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the in-memory layout version 3 of class 'Track' is missing from
# the on-file layout version 3:
#    float T; //
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the in-memory layout version 3 of class 'Track' is missing from
# the on-file layout version 3:
#    float X; //
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the in-memory layout version 3 of class 'Track' is missing from
# the on-file layout version 3:
#    float Y; //
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the in-memory layout version 3 of class 'Track' is missing from
# the on-file layout version 3:
#    float Z; //
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the in-memory layout version 3 of class 'Track' is missing from
# the on-file layout version 3:
#    float TOuter; //
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the in-memory layout version 3 of class 'Track' is missing from
# the on-file layout version 3:
#    float XOuter; //
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the in-memory layout version 3 of class 'Track' is missing from
# the on-file layout version 3:
#    float YOuter; //
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the in-memory layout version 3 of class 'Track' is missing from
# the on-file layout version 3:
#    float ZOuter; //
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the in-memory layout version 3 of class 'Track' is missing from
# the on-file layout version 3:
#    float Xd; //
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the in-memory layout version 3 of class 'Track' is missing from
# the on-file layout version 3:
#    float Yd; //
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the in-memory layout version 3 of class 'Track' is missing from
# the on-file layout version 3:
#    float Zd; //
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the in-memory layout version 3 of class 'Track' is missing from
# the on-file layout version 3:
#    float L; //
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the in-memory layout version 3 of class 'Track' is missing from
# the on-file layout version 3:
#    float D0; //
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the in-memory layout version 3 of class 'Track' is missing from
# the on-file layout version 3:
#    float DZ; //
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the in-memory layout version 3 of class 'Track' is missing from
# the on-file layout version 3:
#    float Nclusters; //
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the in-memory layout version 3 of class 'Track' is missing from
# the on-file layout version 3:
#    float dNdx; //
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the in-memory layout version 3 of class 'Track' is missing from
# the on-file layout version 3:
#    float ErrorP; //
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the in-memory layout version 3 of class 'Track' is missing from
# the on-file layout version 3:
#    float ErrorPT; //
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the in-memory layout version 3 of class 'Track' is missing from
# the on-file layout version 3:
#    float ErrorPhi; //
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the in-memory layout version 3 of class 'Track' is missing from
# the on-file layout version 3:
#    float ErrorCtgTheta; //
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the in-memory layout version 3 of class 'Track' is missing from
# the on-file layout version 3:
#    float ErrorT; //
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the in-memory layout version 3 of class 'Track' is missing from
# the on-file layout version 3:
#    float ErrorD0; //
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the in-memory layout version 3 of class 'Track' is missing from
# the on-file layout version 3:
#    float ErrorDZ; //
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the in-memory layout version 3 of class 'Track' is missing from
# the on-file layout version 3:
#    float ErrorC; //
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the in-memory layout version 3 of class 'Track' is missing from
# the on-file layout version 3:
#    float ErrorD0Phi; //
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the in-memory layout version 3 of class 'Track' is missing from
# the on-file layout version 3:
#    float ErrorD0C; //
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the in-memory layout version 3 of class 'Track' is missing from
# the on-file layout version 3:
#    float ErrorD0DZ; //
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the in-memory layout version 3 of class 'Track' is missing from
# the on-file layout version 3:
#    float ErrorD0CtgTheta; //
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the in-memory layout version 3 of class 'Track' is missing from
# the on-file layout version 3:
#    float ErrorPhiC; //
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the in-memory layout version 3 of class 'Track' is missing from
# the on-file layout version 3:
#    float ErrorPhiDZ; //
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the in-memory layout version 3 of class 'Track' is missing from
# the on-file layout version 3:
#    float ErrorPhiCtgTheta; //
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the in-memory layout version 3 of class 'Track' is missing from
# the on-file layout version 3:
#    float ErrorCDZ; //
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the in-memory layout version 3 of class 'Track' is missing from
# the on-file layout version 3:
#    float ErrorCCtgTheta; //
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the in-memory layout version 3 of class 'Track' is missing from
# the on-file layout version 3:
#    float ErrorDZCtgTheta; //
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the in-memory layout version 3 of class 'Track' is missing from
# the on-file layout version 3:
#    TRef Particle; //
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the in-memory layout version 3 of class 'Track' is missing from
# the on-file layout version 3:
#    int VertexIndex; //
# Warning in <TStreamerInfo::BuildCheck>:
#    The StreamerInfo of class Jet read from file /home/public/3h_1500_1000.root
#    has the same version (=4) as the active class but a different checksum.
#    You should update the version to ClassDef(Jet,5).
#    Do not try to write objects with the current class definition,
#    the files will not be readable.
#
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the in-memory layout version 4 of class 'Jet' is missing from
# the on-file layout version 4:
#    float NeutralEnergyFraction; //
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the in-memory layout version 4 of class 'Jet' is missing from
# the on-file layout version 4:
#    float ChargedEnergyFraction; //
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the in-memory layout version 4 of class 'Jet' is missing from
# the on-file layout version 4:
#    float Beta; //
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the in-memory layout version 4 of class 'Jet' is missing from
# the on-file layout version 4:
#    float BetaStar; //
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the in-memory layout version 4 of class 'Jet' is missing from
# the on-file layout version 4:
#    float MeanSqDeltaR; //
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the in-memory layout version 4 of class 'Jet' is missing from
# the on-file layout version 4:
#    float PTD; //
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the in-memory layout version 4 of class 'Jet' is missing from
# the on-file layout version 4:
#    float FracPt; //
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the in-memory layout version 4 of class 'Jet' is missing from
# the on-file layout version 4:
#    float Tau; //
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the in-memory layout version 4 of class 'Jet' is missing from
# the on-file layout version 4:
#    TLorentzVector SoftDroppedJet; //
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the in-memory layout version 4 of class 'Jet' is missing from
# the on-file layout version 4:
#    TLorentzVector SoftDroppedSubJet1; //
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the in-memory layout version 4 of class 'Jet' is missing from
# the on-file layout version 4:
#    TLorentzVector SoftDroppedSubJet2; //
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the in-memory layout version 4 of class 'Jet' is missing from
# the on-file layout version 4:
#    TLorentzVector TrimmedP4; //
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the in-memory layout version 4 of class 'Jet' is missing from
# the on-file layout version 4:
#    TLorentzVector PrunedP4; //
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the in-memory layout version 4 of class 'Jet' is missing from
# the on-file layout version 4:
#    TLorentzVector SoftDroppedP4; //
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the in-memory layout version 4 of class 'Jet' is missing from
# the on-file layout version 4:
#    int NSubJetsTrimmed; //
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the in-memory layout version 4 of class 'Jet' is missing from
# the on-file layout version 4:
#    int NSubJetsPruned; //
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the in-memory layout version 4 of class 'Jet' is missing from
# the on-file layout version 4:
#    int NSubJetsSoftDropped; //
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the in-memory layout version 4 of class 'Jet' is missing from
# the on-file layout version 4:
#    double ExclYmerge23; //
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the in-memory layout version 4 of class 'Jet' is missing from
# the on-file layout version 4:
#    double ExclYmerge34; //
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the in-memory layout version 4 of class 'Jet' is missing from
# the on-file layout version 4:
#    double ExclYmerge45; //
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the in-memory layout version 4 of class 'Jet' is missing from
# the on-file layout version 4:
#    double ExclYmerge56; //
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the in-memory layout version 4 of class 'Jet' is missing from
# the on-file layout version 4:
#    TRefArray Constituents; //
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the in-memory layout version 4 of class 'Jet' is missing from
# the on-file layout version 4:
#    TRefArray Particles; //
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the in-memory layout version 4 of class 'Jet' is missing from
# the on-file layout version 4:
#    TLorentzVector Area; //
# Error in <TList::Clear>: A list is accessing an object (0x5591d632d390) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x5591d63d3d30) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x5591d63db370) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x5591d63db6e0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x5591d63dba50) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x5591d63dbec0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x5591d63dc230) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x5591d63dc7b0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x5591d63ddb90) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x5591d63de170) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x5591d63de5e0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x5591d63e0120) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x5591d63e0400) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x5591d63ea020) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x5591d63ea390) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x5591d63eb150) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x5591d63fe4d0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x5591d63fe700) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x5591d63fea80) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x5591d64019c0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x5591d6401ea0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x5591d6402480) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x5591d6402af0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x5591d6403fa0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x5591d64050a0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x5591d64064a0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x5591d6406890) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x5591d642fce0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x5591d64300b0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x5591d6430480) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x5591d6430920) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x5591d6430c20) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x5591d6431a60) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x5591d6387d40) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x5591d6388200) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x5591d6388c80) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x5591d6389220) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x5591d6389680) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x5591d6444490) already deleted (list name = TList)
# Error in <THashList::Delete>: A list is accessing an object (0x5591d6baddf0) already deleted (list name = THashList)
# Error in <TList::Delete>: A list is accessing an object (0x5591d704aee0) already deleted (list name = TList)
# Error in <THashList::Delete>: A list is accessing an object (0x5591d6277bd0) already deleted (list name = THashList)

# %%
root_path = '/home/public/3h_1500_850.root'
nbj_min = 4

compute_cutflow_table(root_path, nbj_min=nbj_min)
# Out:
# Number of events: 100000
# 100%|██████████| 10000/10000 [00:53<00:00, 185.53it/s]
# Cut                        n        efficiency passing rate
# total                         10000     1.00     1.00
# >= 6 jets                      7676     0.77     0.77
# >= 4 jets with pT > 40 GeV     7620     0.99     0.76
# >= 4 b-jets                    3812     0.50     0.38
# 3 Higgs                        1429     0.37     0.14
# 2 Higgs                        1702     0.45     0.17
# 1 Higgs                         592     0.16     0.06
#   Event type  Event Fraction  Matching Rate
# 0      Nbj=4        0.588143       0.278769
# 1      Nbj=5        0.319780       0.465956
# 2     Nbj>=6        0.092078       0.672365
# 3      Total        1.000000       0.374869
# \begin{tabular}{c|cc}
#  & Event type & Event Fraction & Matching Rate \\
# 0 & Nbj=4 & 0.588 & 0.279 \\
# 1 & Nbj=5 & 0.320 & 0.466 \\
# 2 & Nbj>=6 & 0.092 & 0.672 \\
# 3 & Total & 1.000 & 0.375 \\
# \end{tabular}
#
#   Event type  Event Fraction  Matching Rate
# 0       Nj=6        0.281217       0.229478
# 1       Nj=7        0.306139       0.371894
# 2      Nj>=8        0.412644       0.476160
# 3      Total        1.000000       0.374869
# \begin{tabular}{c|cc}
#  & Event type & Event Fraction & Matching Rate \\
# 0 & Nj=6 & 0.281 & 0.229 \\
# 1 & Nj=7 & 0.306 & 0.372 \\
# 2 & Nj>=8 & 0.413 & 0.476 \\
# 3 & Total & 1.000 & 0.375 \\
# \end{tabular}
# Warning in <TStreamerInfo::BuildCheck>:
#    The StreamerInfo for version 2 of class GenParticle read from the file /home/public/3h_1500_850.root
#    has a different checksum than the previously loaded StreamerInfo.
#    Reading objects of type GenParticle from the file /home/public/3h_1500_850.root
#    (and potentially other files) might not work correctly.
#    Most likely the version number of the class was not properly
#    updated [See ClassDef(GenParticle,2)].
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 2 of class 'GenParticle' differs from
# the in-memory layout version 2:
#    float T; //number
# vs
#    float CtgTheta; //number
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 2 of class 'GenParticle' differs from
# the in-memory layout version 2:
#    float X; //number
# vs
#    float D0; //number
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 2 of class 'GenParticle' differs from
# the in-memory layout version 2:
#    float Y; //number
# vs
#    float DZ; //number
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 2 of class 'GenParticle' differs from
# the in-memory layout version 2:
#    float Z; //number
# vs
#    float T; //number
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the in-memory layout version 2 of class 'GenParticle' is missing from
# the on-file layout version 2:
#    float X; //number
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the in-memory layout version 2 of class 'GenParticle' is missing from
# the on-file layout version 2:
#    float Y; //number
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the in-memory layout version 2 of class 'GenParticle' is missing from
# the on-file layout version 2:
#    float Z; //number
# Error in <TList::Clear>: A list is accessing an object (0x5591eabf8d50) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x5591eaae8610) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x5591eaa1fae0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x5591ea910e40) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x5591ea886920) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x5591ea7da380) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x5591ea7c87b0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x5591eab5a070) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x5591e174caa0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x5591e1ee2e80) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x5591e25a0d20) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x5591eacaf140) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x5591eacaff80) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x5591eabb9810) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x5591eaba33b0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x5591eaa63190) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x5591eab59400) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x5591eabf2870) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x5591eaa0fd90) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x5591eac60980) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x5591ea9cd360) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x5591eaa26f70) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x5591d736a3b0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x5591eac577c0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x5591eabf1450) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x5591eaa52230) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x5591eaa91040) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x5591eacc9a40) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x5591eacc9df0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x5591eaccd380) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x5591eaccd6e0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x5591eaccd8f0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x5591eacb16d0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x5591eacd3df0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x5591eacd4250) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x5591eacb2cc0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x5591eacb3170) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x5591eacb3420) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x5591eab7e300) already deleted (list name = TList)
# Error in <THashList::Delete>: A list is accessing an object (0x5591eaaee210) already deleted (list name = THashList)
# Error in <TList::Delete>: A list is accessing an object (0x5591eb501a70) already deleted (list name = TList)
# Error in <THashList::Delete>: A list is accessing an object (0x5591eac96250) already deleted (list name = THashList)

# %%
root_path = '/home/public/3h_1300_1000.root'
nbj_min = 4

compute_cutflow_table(root_path, nbj_min=nbj_min)
# Out:
# Number of events: 100000
#   0%|          | 0/10000 [00:00<?, ?it/s]
# 100%|██████████| 10000/10000 [00:53<00:00, 185.40it/s]
# Cut                        n        efficiency passing rate
# total                         10000     1.00     1.00
# >= 6 jets                      7738     0.77     0.77
# >= 4 jets with pT > 40 GeV     7643     0.99     0.76
# >= 4 b-jets                    3916     0.51     0.39
# 3 Higgs                        1483     0.38     0.15
# 2 Higgs                        1621     0.41     0.16
# 1 Higgs                         711     0.18     0.07
#   Event type  Event Fraction  Matching Rate
# 0      Nbj=4        0.577886       0.293858
# 1      Nbj=5        0.324055       0.446809
# 2     Nbj>=6        0.098059       0.653646
# 3      Total        1.000000       0.378703
# \begin{tabular}{c|cc}
#  & Event type & Event Fraction & Matching Rate \\
# 0 & Nbj=4 & 0.578 & 0.294 \\
# 1 & Nbj=5 & 0.324 & 0.447 \\
# 2 & Nbj>=6 & 0.098 & 0.654 \\
# 3 & Total & 1.000 & 0.379 \\
# \end{tabular}
#
#   Event type  Event Fraction  Matching Rate
# 0       Nj=6        0.282431       0.253165
# 1       Nj=7        0.322778       0.374209
# 2      Nj>=8        0.394791       0.472186
# 3      Total        1.000000       0.378703
# \begin{tabular}{c|cc}
#  & Event type & Event Fraction & Matching Rate \\
# 0 & Nj=6 & 0.282 & 0.253 \\
# 1 & Nj=7 & 0.323 & 0.374 \\
# 2 & Nj>=8 & 0.395 & 0.472 \\
# 3 & Total & 1.000 & 0.379 \\
# \end{tabular}
# Error in <TList::Clear>: A list is accessing an object (0x5591f2378560) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x5591f0e82290) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x5591f18ac910) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x5591f55db760) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x5591ebfb46e0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x5591ebfb3260) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x5591ebfb1de0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x5591f30d7ba0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x5591f0d91fe0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x5591f0610780) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x5591f0340000) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x5591fe6dbed0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x5591fe6dc120) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x5591eacd5f90) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x5591eacd60d0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x5591eacd6bf0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x5591eacd71b0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x5591eacd72f0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x5591eacd7470) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x5591eacd9490) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x5591eacd97f0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x5591eacd9cb0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x5591eacda170) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x5591eacdb1c0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x5591eacdc130) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x5591eacdd2f0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x5591eacdd680) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x5591eacdf550) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x5591eacdf900) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x5591eacdfbe0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x5591eacdff90) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x5591eace01d0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x5591eace0a50) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x5591eb922f30) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x5591eb923390) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x5591eb923b40) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x5591eb923ff0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x5591eb9242a0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x5591eabf8660) already deleted (list name = TList)
# Error in <THashList::Delete>: A list is accessing an object (0x5591ea941960) already deleted (list name = THashList)
# Error in <TList::Delete>: A list is accessing an object (0x5591ff724f00) already deleted (list name = TList)
# Error in <THashList::Delete>: A list is accessing an object (0x5591ea9e5e50) already deleted (list name = THashList)
