# %%
import sys
import ROOT

import numpy as np
import pandas as pd

from tqdm import tqdm

sys.path.append('..')
import utils_HDF5 as utils

delphes_path = '/usr/local/Delphes-3.4.2'
ROOT.gROOT.ProcessLine(f'.include {delphes_path}/')
ROOT.gROOT.ProcessLine(f'.include {delphes_path}/external/')
ROOT.gInterpreter.Declare(f'#include "{delphes_path}/classes/DelphesClasses.h"')
ROOT.gSystem.Load(f'{delphes_path}/install/lib/libDelphes')

MAX_JETS = 15
# Out:
# Welcome to JupyROOT 6.20/08

# %%
def DeltaR(eta1, phi1, eta2, phi2):
    dEta = eta1 - eta2
    dPhi = np.abs(phi1 - phi2)

    dPhi = np.where(dPhi > np.pi, 2 * np.pi - dPhi, dPhi)

    dR = np.sqrt(dPhi**2 + dEta**2)
    return dR

# %%
def print_cutflow_table(counts):
    n_tot = counts['total']
    n_previous = counts['total']
    print(f"{'Cut':<26} {'n':8} {'efficiency':8} {'passing rate':8}")
    for key, value in counts.items():
        if key not in ['3 Higgs', '2 Higgs', '1 Higgs']:
            print(f'{key:<26} {value:>8} {value / n_previous:>8.2f} {value / n_tot:>8.2f}')
            n_previous = value
        else:
            print(f'{key:<26} {value:>8} {value / n_previous:>8.2f} {value / n_tot:>8.2f}')

# %%
def print_matching_table(total_event, matched_event, nj=(6, 8), jet_type='Nj'):

    start, end = nj

    event_type = [f'{jet_type}={nj}' for nj in range(start, end)]
    event_type.append(f'{jet_type}>={end}')
    event_type.append('Total')

    event_fraction = [total_event[nj] / total_event.sum() for nj in range(start, end)]
    event_fraction.append(total_event[end:].sum() / total_event.sum())
    event_fraction.append(total_event.sum() / total_event.sum())

    matching_rate = [matched_event[nj] / total_event[nj].sum() for nj in range(start, end)]
    matching_rate.append(matched_event[end:].sum() / total_event[end:].sum())
    matching_rate.append(matched_event.sum() / total_event.sum())

        
    result = {
              'Event type': event_type,
              'Event Fraction': event_fraction,
              'Matching Rate': matching_rate,
             }

    df = pd.DataFrame(result)
    print(df)

    df_style = df.style.format({
            'Event Fraction': '{:.3f}',
            'Matching Rate': '{:.3f}',
        })
    print(df_style.to_latex(column_format='c|cc'))

# %%
def select_event(root_path, nbj_min, start, end):
    counts = {
        'total': 0,
        '>= 6 jets': 0,
        '>= 4 jets with pT > 40 GeV': 0,
        '>= 4 b-jets': 0,
        '3 Higgs': 0,
        '2 Higgs': 0,
        '1 Higgs': 0,
    }

    total_event_bjet = np.zeros(MAX_JETS + 1)
    matched_event_bjet = np.zeros(MAX_JETS + 1)
    total_event_Njet = np.zeros(MAX_JETS + 1)
    matched_event_Njet = np.zeros(MAX_JETS + 1)

    f = ROOT.TFile(root_path)
    tree = f.Get("Delphes")

    for i in tqdm(range(start, end)):
        tree.GetEntry(i)

        # 夸克資料
        # b夸克 衰變前的編號
        quarks_id = []
        quarks_Eta = []
        quarks_Phi = []
        quarks_Jet = np.array([-1, -1, -1, -1, -1, -1])

        # 找出 3 個 final Higgs
        final_h_index = []
        for index, particle in enumerate(tree.Particle):
            if particle.PID == 25:
                h = index
                d1 = tree.Particle[h].D1
                while tree.Particle[d1].PID == 25:
                    h = d1
                    d1 = tree.Particle[h].D1
                final_h_index.append(h)

        final_h_index = list(set(final_h_index))

        # 找出 6 個 final b quark
        for h in final_h_index:
            # h > b b~
            b1 = tree.Particle[h].D1
            b2 = tree.Particle[h].D2

            # 找出 b 衰變前的編號
            d1 = tree.Particle[b1].D1
            while abs(tree.Particle[d1].PID) == 5:
                b1 = d1
                d1 = tree.Particle[b1].D1

            # 找出 b~ 衰變前的編號
            d2 = tree.Particle[b2].D1
            while abs(tree.Particle[d2].PID) == 5:
                b2 = d2
                d2 = tree.Particle[b2].D1

            quarks_id.extend([b1, b2])

        quarks_Eta.extend(tree.Particle[quark].Eta for quark in quarks_id)
        quarks_Phi.extend(tree.Particle[quark].Phi for quark in quarks_id)

        # 事件中的 jet 資料
        jet_PT = np.array([jet.PT for jet in tree.Jet])
        jet_Eta = np.array([jet.Eta for jet in tree.Jet])
        jet_Phi = np.array([jet.Phi for jet in tree.Jet])
        jet_Mass = np.array([jet.Mass for jet in tree.Jet])
        jet_BTag = np.array([jet.BTag for jet in tree.Jet])

        # Jet 資料
        # |eta| < 2.5 & PT > 20 GeV
        eta_pt_cut = np.array((np.abs(jet_Eta) < 2.5) & (jet_PT > 20))
        # |eta| < 2.5 & PT > 40 GeV
        eta_pt40_cut = np.array((np.abs(jet_Eta) < 2.5) & (jet_PT > 40))

        nj = eta_pt_cut.sum()

        counts['total'] += 1
        # 至少要 6 jet
        if nj < 6:
            continue
        counts['>= 6 jets'] += 1
        # 至少要 4 jet pT > 40 GeV
        if eta_pt40_cut.sum() < 4:
            continue
        counts['>= 4 jets with pT > 40 GeV'] += 1
        nbj = np.array(jet_BTag[eta_pt_cut][:MAX_JETS]).sum()
        # 在前 MAX_JETS jets 中，至少要 nbj_min 個 b-jet
        if nbj < nbj_min:
            continue
        counts['>= 4 b-jets'] += 1
        total_event_bjet[nbj] += 1
        total_event_Njet[nj] += 1

        # PT = np.array(jet_PT[eta_pt_cut])
        Eta = np.array(jet_Eta[eta_pt_cut])
        Phi = np.array(jet_Phi[eta_pt_cut])
        # Mass = np.array(jet_Mass[eta_pt_cut])
        # BTag = np.array(jet_BTag[eta_pt_cut])

        # 找出每個夸克配對的 jet
        # more_than_1_jet = False
        for quark in range(len(quarks_Jet)):
            dR = DeltaR(quarks_Eta[quark], quarks_Phi[quark], Eta, Phi)
            if dR.min() < 0.4:
                quarks_Jet[quark] = np.argmin(dR)


        quark_jet = quarks_Jet.reshape(1, 6)

        h1_mask = utils.get_particle_mask(quark_jet, [0, 1])
        h2_mask = utils.get_particle_mask(quark_jet, [2, 3])
        h3_mask = utils.get_particle_mask(quark_jet, [4, 5])

        nh = [h1_mask, h2_mask, h3_mask].count(True)

        if nh == 3:
            counts['3 Higgs'] += 1
            matched_event_bjet[nbj] += 1
            matched_event_Njet[nj] += 1
        elif nh == 2:
            counts['2 Higgs'] += 1
        elif nh == 1:
            counts['1 Higgs'] += 1
       
    print_cutflow_table(counts)
    print_matching_table(total_event_bjet, matched_event_bjet, (4, 11), 'Nbj')
    print_matching_table(total_event_Njet, matched_event_Njet, (6, 8), 'Nj')

# %%
def compute_cutflow_table(root_path, nbj_min=0):
    f = ROOT.TFile(root_path)
    nevent = f.Get("Delphes").GetEntries()
    print(f'Number of events: {nevent}')

    start = 0
    end = nevent
    # end = 1000

    select_event(root_path, nbj_min, start, end)

# %%
root_path = './MG5/gghhh_bsm/Events/run_01_decayed_1/tag_2_delphes_events.root'
nbj_min = 4

compute_cutflow_table(root_path, nbj_min=nbj_min)
# Out:
# Number of events: 100000
# 100%|██████████| 100000/100000 [09:22<00:00, 177.83it/s]
# Cut                        n        efficiency passing rate
# total                        100000     1.00     1.00
# >= 6 jets                     61454     0.61     0.61
# >= 4 jets with pT > 40 GeV    50341     0.82     0.50
# >= 4 b-jets                   32337     0.64     0.32
# 3 Higgs                        9944     0.31     0.10
# 2 Higgs                       11341     0.35     0.11
# 1 Higgs                        8941     0.28     0.09
#   Event type  Event Fraction  Matching Rate
# 0      Nbj=4        0.509107       0.186843
# 1      Nbj=5        0.368247       0.353796
# 2      Nbj=6        0.112626       0.669138
# 3      Nbj=7        0.009401       0.674342
# 4      Nbj=8        0.000618       0.650000
# 5     Nbj>=9        0.000000            NaN
# 6      Total        1.000000       0.307512
# \begin{tabular}{c|cc}
#  & Event type & Event Fraction & Matching Rate \\
# 0 & Nbj=4 & 0.509 & 0.187 \\
# 1 & Nbj=5 & 0.368 & 0.354 \\
# 2 & Nbj=6 & 0.113 & 0.669 \\
# 3 & Nbj=7 & 0.009 & 0.674 \\
# 4 & Nbj=8 & 0.001 & 0.650 \\
# 5 & Nbj>=9 & 0.000 & nan \\
# 6 & Total & 1.000 & 0.308 \\
# \end{tabular}
#
#   Event type  Event Fraction  Matching Rate
# 0       Nj=6        0.341126       0.218385
# 1       Nj=7        0.320469       0.321722
# 2      Nj>=8        0.338405       0.383898
# 3      Total        1.000000       0.307512
# \begin{tabular}{c|cc}
#  & Event type & Event Fraction & Matching Rate \\
# 0 & Nj=6 & 0.341 & 0.218 \\
# 1 & Nj=7 & 0.320 & 0.322 \\
# 2 & Nj>=8 & 0.338 & 0.384 \\
# 3 & Total & 1.000 & 0.308 \\
# \end{tabular}
# /tmp/ipykernel_2843966/2570250950.py:14: RuntimeWarning: invalid value encountered in scalar divide
#   matching_rate.append(matched_event[end:].sum() / total_event[end:].sum())

# %%
root_path = './MG5/pphhh_sm/Events/run_01_decayed_1/tag_1_delphes_events.root'
nbj_min = 4

compute_cutflow_table(root_path, nbj_min=nbj_min)
# Out:
# Number of events: 100000
# 100%|██████████| 100000/100000 [11:04<00:00, 150.42it/s]
# /tmp/ipykernel_2843966/2570250950.py:14: RuntimeWarning: invalid value encountered in scalar divide
#   matching_rate.append(matched_event[end:].sum() / total_event[end:].sum())
# Cut                        n        efficiency passing rate
# total                        100000     1.00     1.00
# >= 6 jets                     74878     0.75     0.75
# >= 4 jets with pT > 40 GeV    70399     0.94     0.70
# >= 4 b-jets                   48734     0.69     0.49
# 3 Higgs                       17599     0.36     0.18
# 2 Higgs                       18601     0.38     0.19
# 1 Higgs                       10759     0.22     0.11
#   Event type  Event Fraction  Matching Rate
# 0      Nbj=4        0.474966       0.227416
# 1      Nbj=5        0.377806       0.395449
# 2      Nbj=6        0.131818       0.701743
# 3      Nbj=7        0.013933       0.723122
# 4      Nbj=8        0.001354       0.742424
# 5      Nbj=9        0.000103       1.000000
# 6     Nbj=10        0.000021       1.000000
# 7    Nbj>=11        0.000000            NaN
# 8      Total        1.000000       0.361124
# \begin{tabular}{c|cc}
#  & Event type & Event Fraction & Matching Rate \\
# 0 & Nbj=4 & 0.475 & 0.227 \\
# 1 & Nbj=5 & 0.378 & 0.395 \\
# 2 & Nbj=6 & 0.132 & 0.702 \\
# 3 & Nbj=7 & 0.014 & 0.723 \\
# 4 & Nbj=8 & 0.001 & 0.742 \\
# 5 & Nbj=9 & 0.000 & 1.000 \\
# 6 & Nbj=10 & 0.000 & 1.000 \\
# 7 & Nbj>=11 & 0.000 & nan \\
# 8 & Total & 1.000 & 0.361 \\
# \end{tabular}
#
#   Event type  Event Fraction  Matching Rate
# 0       Nj=6        0.281754       0.226713
# 1       Nj=7        0.307137       0.352418
# 2      Nj>=8        0.411109       0.459745
# 3      Total        1.000000       0.361124
# \begin{tabular}{c|cc}
#  & Event type & Event Fraction & Matching Rate \\
# 0 & Nj=6 & 0.282 & 0.227 \\
# 1 & Nj=7 & 0.307 & 0.352 \\
# 2 & Nj>=8 & 0.411 & 0.460 \\
# 3 & Total & 1.000 & 0.361 \\
# \end{tabular}

# %%
root_path = '/home/public/3h_1500_1000.root'
nbj_min = 4

compute_cutflow_table(root_path, nbj_min=nbj_min)
# Out:
# Number of events: 100000
# 100%|██████████| 1000/1000 [00:05<00:00, 167.73it/s]
# Cut                        n        efficiency passing rate
# total                          1000     1.00     1.00
# >= 6 jets                       744     0.74     0.74
# >= 4 jets with pT > 40 GeV      739     0.99     0.74
# >= 4 b-jets                     355     0.48     0.35
# 3 Higgs                         115     0.32     0.12
# 2 Higgs                         177     0.50     0.18
# 1 Higgs                          52     0.15     0.05
#   Event type  Event Fraction  Matching Rate
# 0      Nbj=4        0.636620       0.247788
# 1      Nbj=5        0.315493       0.446429
# 2     Nbj>=6        0.047887       0.529412
# 3      Total        1.000000       0.323944
# \begin{tabular}{c|cc}
#  & Event type & Event Fraction & Matching Rate \\
# 0 & Nbj=4 & 0.637 & 0.248 \\
# 1 & Nbj=5 & 0.315 & 0.446 \\
# 2 & Nbj>=6 & 0.048 & 0.529 \\
# 3 & Total & 1.000 & 0.324 \\
# \end{tabular}
#
#   Event type  Event Fraction  Matching Rate
# 0       Nj=6        0.301408       0.186916
# 1       Nj=7        0.298592       0.377358
# 2      Nj>=8        0.400000       0.387324
# 3      Total        1.000000       0.323944
# \begin{tabular}{c|cc}
#  & Event type & Event Fraction & Matching Rate \\
# 0 & Nj=6 & 0.301 & 0.187 \\
# 1 & Nj=7 & 0.299 & 0.377 \\
# 2 & Nj>=8 & 0.400 & 0.387 \\
# 3 & Total & 1.000 & 0.324 \\
# \end{tabular}
# Error in <THashList::Delete>: A list is accessing an object (0x559303613d40) already deleted (list name = THashList)
# Error in <THashList::Delete>: A list is accessing an object (0x55930361f120) already deleted (list name = THashList)

# %%
root_path = '/home/public/3h_1500_850.root'
nbj_min = 4

compute_cutflow_table(root_path, nbj_min=nbj_min)
# Out:
# Number of events: 100000
# 100%|██████████| 1000/1000 [00:05<00:00, 175.00it/s]
# Cut                        n        efficiency passing rate
# total                          1000     1.00     1.00
# >= 6 jets                       771     0.77     0.77
# >= 4 jets with pT > 40 GeV      768     1.00     0.77
# >= 4 b-jets                     376     0.49     0.38
# 3 Higgs                         134     0.36     0.13
# 2 Higgs                         171     0.45     0.17
# 1 Higgs                          62     0.16     0.06
#   Event type  Event Fraction  Matching Rate
# 0      Nbj=4        0.590426       0.229730
# 1      Nbj=5        0.329787       0.491935
# 2     Nbj>=6        0.079787       0.733333
# 3      Total        1.000000       0.356383
# \begin{tabular}{c|cc}
#  & Event type & Event Fraction & Matching Rate \\
# 0 & Nbj=4 & 0.590 & 0.230 \\
# 1 & Nbj=5 & 0.330 & 0.492 \\
# 2 & Nbj>=6 & 0.080 & 0.733 \\
# 3 & Total & 1.000 & 0.356 \\
# \end{tabular}
#
#   Event type  Event Fraction  Matching Rate
# 0       Nj=6        0.303191       0.175439
# 1       Nj=7        0.268617       0.316832
# 2      Nj>=8        0.428191       0.509317
# 3      Total        1.000000       0.356383
# \begin{tabular}{c|cc}
#  & Event type & Event Fraction & Matching Rate \\
# 0 & Nj=6 & 0.303 & 0.175 \\
# 1 & Nj=7 & 0.269 & 0.317 \\
# 2 & Nj>=8 & 0.428 & 0.509 \\
# 3 & Total & 1.000 & 0.356 \\
# \end{tabular}
# Warning in <TStreamerInfo::BuildCheck>:
#    The StreamerInfo for version 2 of class GenParticle read from the file /home/public/3h_1500_850.root
#    has a different checksum than the previously loaded StreamerInfo.
#    Reading objects of type GenParticle from the file /home/public/3h_1500_850.root
#    (and potentially other files) might not work correctly.
#    Most likely the version number of the class was not properly
#    updated [See ClassDef(GenParticle,2)].
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 2 of class 'GenParticle' differs from
# the in-memory layout version 2:
#    float T; //number
# vs
#    float CtgTheta; //number
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 2 of class 'GenParticle' differs from
# the in-memory layout version 2:
#    float X; //number
# vs
#    float D0; //number
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 2 of class 'GenParticle' differs from
# the in-memory layout version 2:
#    float Y; //number
# vs
#    float DZ; //number
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the on-file layout version 2 of class 'GenParticle' differs from
# the in-memory layout version 2:
#    float Z; //number
# vs
#    float T; //number
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the in-memory layout version 2 of class 'GenParticle' is missing from
# the on-file layout version 2:
#    float X; //number
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the in-memory layout version 2 of class 'GenParticle' is missing from
# the on-file layout version 2:
#    float Y; //number
# Warning in <TStreamerInfo::CompareContent>: The following data member of
# the in-memory layout version 2 of class 'GenParticle' is missing from
# the on-file layout version 2:
#    float Z; //number
# Error in <TList::Clear>: A list is accessing an object (0x55930e504c30) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x55930ac34b90) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x55930e037440) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x55930e060cc0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x55930d2b6bd0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x55930d356cd0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x55930d35bbd0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x55930ac401c0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x55930eddd050) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x55930f19a760) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x55930f92d650) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x55930ea78ba0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x55930f77cf80) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x55930f7dd910) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x55930e5061f0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x55930eac0e50) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x55930e2c99c0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x55930e4f22b0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x55930f77e120) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x55930ac355d0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x55930ea9c610) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x55930e4e0810) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x55930eacec00) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x55930eab54d0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x55930e2ab950) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x55930ac499a0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x55930e4d9780) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x55930eabac00) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x5592f9d1b6a0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x5592fbd9c610) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x5592fbd9c9c0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x55930e9cbae0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x5592fce45a90) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x55930e9c8850) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x55930e9c8cb0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x5592fce4cb70) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x5592fce4d020) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x559300d93b70) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x55930faed760) already deleted (list name = TList)
# Error in <THashList::Delete>: A list is accessing an object (0x55930ea93f30) already deleted (list name = THashList)
# Error in <TList::Delete>: A list is accessing an object (0x559308c5d2e0) already deleted (list name = TList)
# Error in <THashList::Delete>: A list is accessing an object (0x55930e989300) already deleted (list name = THashList)

# %%
root_path = '/home/public/3h_1300_1000.root'
nbj_min = 4

compute_cutflow_table(root_path, nbj_min=nbj_min)
# Out:
# Number of events: 100000
# 100%|██████████| 1000/1000 [00:05<00:00, 177.00it/s]
# Cut                        n        efficiency passing rate
# total                          1000     1.00     1.00
# >= 6 jets                       765     0.77     0.77
# >= 4 jets with pT > 40 GeV      755     0.99     0.76
# >= 4 b-jets                     400     0.53     0.40
# 3 Higgs                         141     0.35     0.14
# 2 Higgs                         173     0.43     0.17
# 1 Higgs                          74     0.18     0.07
#   Event type  Event Fraction  Matching Rate
# 0      Nbj=4           0.540       0.231481
# 1      Nbj=5           0.345       0.427536
# 2     Nbj>=6           0.115       0.695652
# 3      Total           1.000       0.352500
# \begin{tabular}{c|cc}
#  & Event type & Event Fraction & Matching Rate \\
# 0 & Nbj=4 & 0.540 & 0.231 \\
# 1 & Nbj=5 & 0.345 & 0.428 \\
# 2 & Nbj>=6 & 0.115 & 0.696 \\
# 3 & Total & 1.000 & 0.352 \\
# \end{tabular}
#
#   Event type  Event Fraction  Matching Rate
# 0       Nj=6          0.2875       0.173913
# 1       Nj=7          0.3100       0.419355
# 2      Nj>=8          0.4025       0.428571
# 3      Total          1.0000       0.352500
# \begin{tabular}{c|cc}
#  & Event type & Event Fraction & Matching Rate \\
# 0 & Nj=6 & 0.287 & 0.174 \\
# 1 & Nj=7 & 0.310 & 0.419 \\
# 2 & Nj>=8 & 0.403 & 0.429 \\
# 3 & Total & 1.000 & 0.352 \\
# \end{tabular}
# Error in <TList::Clear>: A list is accessing an object (0x5593076580c0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x55930361f980) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x55930b6e7ed0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x5593089a5f60) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x559308c62660) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x559308c611e0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x5593089a79f0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x55930b6ebd50) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x559308f26370) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x559308f23030) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x5593091d02d0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x55930cfbeeb0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x55930cfbf100) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x559319c414a0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x559319c415e0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x559319c42140) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x559319c42700) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x559319c42840) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x559319c429c0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x559319c449e0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x559319c44d40) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x559319c45200) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x559319c456c0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x559319c46800) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x559319c47770) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x559319c48930) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x559319c48cc0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x559319c4ac70) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x559319c4b020) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x559319c4b300) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x559319c4b6b0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x559319c4b8f0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x559319c4c170) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x559319c53540) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x559319c539a0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x559319c54150) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x559319c54600) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x559319c548b0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x559319c54e90) already deleted (list name = TList)
# Error in <THashList::Delete>: A list is accessing an object (0x55930af85bc0) already deleted (list name = THashList)
# Error in <TList::Delete>: A list is accessing an object (0x5593162a16a0) already deleted (list name = TList)
# Error in <THashList::Delete>: A list is accessing an object (0x55930e790dd0) already deleted (list name = THashList)
