# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def load_DNN_feature(file):
    results = np.load(file)

    results = {'dR1': results[:, 0],
            'dR2': results[:, 1],
            'dR3': results[:, 2],
            'rms_dR': results[:, 3],
            'dA_skew': results[:, 4],
            'HT': results[:, 5],
            'mhCostheta': results[:, 6],
            'eta_mhhh_fraction': results[:, 7],
            'sphericity': results[:, 8],
            'aplanarity': results[:, 9]}

    return results

# %%
results_res = load_DNN_feature('./DNN_features/resonant-abs_pairing.npy')

# %%
results_6b = load_DNN_feature('DNN_features/pp6b-abs_pairing.npy')

# %%
# plot dR distribution
fig, ax = plt.subplots(1, 3, figsize=(15, 4))

for i in range(3):
    # normalize the histogram

    ax[i].hist(results_6b[f'dR{i+1}'], bins=20, range=(0, 4.5), histtype='step', density=True, label='Background')
    ax[i].hist(results_res[f'dR{i+1}'], bins=20, range=(0, 4.5), histtype='step', density=True, label=f'Signal')
    ax[i].legend(frameon=False)
    ax[i].set_xlabel('$\Delta R$')
    ax[i].set_ylabel('Normalized counts')
    ax[i].set_title(f'$\Delta R_{i+1}$ distribution')

plt.savefig('../figures/dR_distribution-abs_pairing.pdf', dpi=300, facecolor='White', bbox_inches='tight')
plt.show()

# %%
# plot RMS of dR distribution
fig, ax = plt.subplots(1, 1, figsize=(5, 4))

ax.hist(results_6b['rms_dR'], bins=20, range=(0, 5), histtype='step', density=True, label='Background')
ax.hist(results_res['rms_dR'], bins=20, range=(0, 5), histtype='step', density=True, label='Signal')
ax.legend(frameon=False)
ax.set_xlabel('RMS of $\Delta R$')
ax.set_ylabel('Normalized counts')
ax.set_title('RMS of $\Delta R$ distribution')

plt.savefig('../figures/rms_dR_distribution-abs_pairing.pdf', dpi=300, facecolor='White', bbox_inches='tight')
plt.show()

# %%
# plot skewness of dA distribution
fig, ax = plt.subplots(1, 1, figsize=(5, 4))

ax.hist(results_6b['dA_skew'], bins=20, range=(-1, 3.5), histtype='step', density=True, label='Background')
ax.hist(results_res['dA_skew'], bins=20, range=(-1, 3.5), histtype='step', density=True, label='Signal')
ax.legend(frameon=False)
ax.set_xlabel('Skewness of $\Delta A$')
ax.set_ylabel('Normalized counts')
ax.set_title('Skewness of $\Delta A$ distribution')

plt.savefig('../figures/dA_skew_distribution-abs_pairing.pdf', dpi=300, facecolor='White', bbox_inches='tight')
plt.show()

# %%
# plot HT distribution
fig, ax = plt.subplots(1, 1, figsize=(5, 4))

ax.hist(results_6b['HT'], bins=20, range=(200, 1600), histtype='step', density=True, label='Background')
ax.hist(results_res['HT'], bins=20, range=(200, 1600), histtype='step', density=True, label='Signal')
ax.legend(frameon=False)
ax.set_xlabel('$H_{T, \mathrm{6jets}}$ (GeV)')
ax.set_ylabel('Normalized counts')
ax.set_title('$H_T$ distribution')

plt.savefig('../figures/HT_distribution-abs_pairing.pdf', dpi=300, facecolor='White', bbox_inches='tight')
plt.show()

# %%
# plot mhCostheta distribution
fig, ax = plt.subplots(1, 1, figsize=(5, 4))

ax.hist(results_6b['mhCostheta'], bins=20, range=(-1.0, 1.0), histtype='step', density=True, label='Background')
ax.hist(results_res['mhCostheta'], bins=20, range=(-1.0, 1.0), histtype='step', density=True, label='Signal')
ax.legend(frameon=False)
ax.set_xlabel('$m_h\cos\\theta$')
ax.set_ylabel('Normalized counts')
ax.set_title('$m_h\cos\\theta$ distribution')

plt.savefig('../figures/mhCostheta_distribution-abs_pairing.pdf', dpi=300, facecolor='White', bbox_inches='tight')
plt.show()

# %%
# plot eta-mhhh distribution
fig, ax = plt.subplots(1, 1, figsize=(5, 4))

ax.hist(results_6b['eta_mhhh_fraction'], bins=20, range=(0, 1), histtype='step', density=True, label='Background')
ax.hist(results_res['eta_mhhh_fraction'], bins=20, range=(0, 1), histtype='step', density=True, label='Signal')
ax.legend(frameon=False)
ax.set_xlabel('$\eta - m_{hhh}$ fraction')
ax.set_ylabel('Normalized counts')
ax.set_title('$\eta - m_{hhh}$ fraction distribution')

plt.savefig('../figures/eta_mhhh_fraction_distribution-abs_pairing.pdf', dpi=300, facecolor='White', bbox_inches='tight')
plt.show()

# %%
# plot sphericity distribution
fig, ax = plt.subplots(1, 1, figsize=(5, 4))

ax.hist(results_6b['sphericity'], bins=20, histtype='step', density=True, label='Background')
ax.hist(results_res['sphericity'], bins=20, histtype='step', density=True, label='Signal')
ax.legend(frameon=False)
ax.set_xlabel('Sphericity')
ax.set_ylabel('Normalized counts')
ax.set_title('Sphericity distribution')

plt.savefig('../figures/sphericity_distribution-abs_pairing.pdf', dpi=300, facecolor='White', bbox_inches='tight')
plt.show()

# %%
# plot aplanarity distribution
fig, ax = plt.subplots(1, 1, figsize=(5, 4))

ax.hist(results_6b['aplanarity'], bins=20, range=(0, 0.4), histtype='step', density=True, label='Background')
ax.hist(results_res['aplanarity'], bins=20, range=(0, 0.4), histtype='step', density=True, label='Signal')
ax.legend(frameon=False)
ax.set_xlabel('Aplanarity')
ax.set_ylabel('Normalized counts')
ax.set_title('Aplanarity distribution')

plt.savefig('../figures/aplanarity_distribution-abs_pairing.pdf', dpi=300, facecolor='White', bbox_inches='tight')
plt.show()

# %% [markdown]
# # Different pairing methods

# %%
results_res_abs = load_DNN_feature('./DNN_features/resonant-abs_pairing.npy')
results_res_chi2 = load_DNN_feature('./DNN_features/resonant-chi2_pairing.npy')
results_res_SPANet = load_DNN_feature('./DNN_features/resonant-4b_SPANet_pairing.npy')
results_res_truth = load_DNN_feature('./DNN_features/resonant-truth_pairing.npy')

# %%
results_6b_abs = load_DNN_feature('DNN_features/pp6b-abs_pairing.npy')
results_6b_chi2 = load_DNN_feature('DNN_features/pp6b-chi2_pairing.npy')
results_6b_SPANet = load_DNN_feature('DNN_features/pp6b-4b_SPANet_pairing.npy')

# %%
# plot dR distribution
fig, ax = plt.subplots(1, 3, figsize=(15, 4))

for i in range(3):

    ax[i].hist(results_res_abs[f'dR{i+1}'], bins=20, range=(0, 4.5), histtype='step', density=True, label=f'$|m - m_h|$')
    ax[i].hist(results_res_chi2[f'dR{i+1}'], bins=20, range=(0, 4.5), histtype='step', density=True, label=f'$(m - m_h)^2$')
    ax[i].hist(results_res_SPANet[f'dR{i+1}'], bins=20, range=(0, 4.5), histtype='step', density=True, label=f'SPANet')
    ax[i].hist(results_res_truth[f'dR{i+1}'], bins=20, range=(0, 4.5), histtype='step', density=True, label=f'Truth')

    ax[i].legend(frameon=False, loc='upper left')
    ax[i].set_xlabel('$\Delta R$')
    ax[i].set_ylabel('Normalized counts')
    ax[i].set_title(f'$\Delta R_{i+1}$ distribution')

plt.savefig('../figures/dR_distribution_signal.pdf', dpi=300, facecolor='White', bbox_inches='tight')
plt.show()

# plot dR distribution
fig, ax = plt.subplots(1, 3, figsize=(15, 4))

for i in range(3):

    ax[i].hist(results_6b_abs[f'dR{i+1}'], bins=20, range=(0, 4.5), histtype='step', density=True, label=f'$|m - m_h|$')
    ax[i].hist(results_6b_chi2[f'dR{i+1}'], bins=20, range=(0, 4.5), histtype='step', density=True, label=f'$(m - m_h)^2$')
    ax[i].hist(results_6b_SPANet[f'dR{i+1}'], bins=20, range=(0, 4.5), histtype='step', density=True, label='SPANet')

    ax[i].legend(frameon=False, loc='upper left')
    ax[i].set_xlabel('$\Delta R$')
    ax[i].set_ylabel('Normalized counts')
    ax[i].set_title(f'$\Delta R_{i+1}$ distribution')

plt.savefig('../figures/dR_distribution_background.pdf', dpi=300, facecolor='White', bbox_inches='tight')
plt.show()

# %%
# plot RMS of dR distribution
fig, ax = plt.subplots(1, 1, figsize=(5, 4))

ax.hist(results_res_abs['rms_dR'], bins=20, range=(0, 5), histtype='step', density=True, label=f'$|m - m_h|$')
ax.hist(results_res_chi2['rms_dR'], bins=20, range=(0, 5), histtype='step', density=True, label=f'$(m - m_h)^2$')
ax.hist(results_res_SPANet['rms_dR'], bins=20, range=(0, 5), histtype='step', density=True, label=f'SPANet')
ax.hist(results_res_truth['rms_dR'], bins=20, range=(0, 5), histtype='step', density=True, label=f'Truth')

ax.legend(frameon=False, loc='upper left')
ax.set_xlabel('RMS of $\Delta R$')
ax.set_ylabel('Normalized counts')
ax.set_title('RMS of $\Delta R$ distribution')

# plt.savefig('../figures/rms_dR_distribution-abs_pairing.pdf', dpi=300, facecolor='White', bbox_inches='tight')
plt.show()

# plot RMS of dR distribution
fig, ax = plt.subplots(1, 1, figsize=(5, 4))

ax.hist(results_6b_abs['rms_dR'], bins=20, range=(0, 5), histtype='step', density=True, label=f'$|m - m_h|$')
ax.hist(results_6b_chi2['rms_dR'], bins=20, range=(0, 5), histtype='step', density=True, label=f'$(m - m_h)^2$')
ax.hist(results_6b_SPANet['rms_dR'], bins=20, range=(0, 5), histtype='step', density=True, label=f'SPANet')

ax.legend(frameon=False, loc='upper left')
ax.set_xlabel('RMS of $\Delta R$')
ax.set_ylabel('Normalized counts')
ax.set_title('RMS of $\Delta R$ distribution')

# plt.savefig('../figures/rms_dR_distribution-abs_pairing.pdf', dpi=300, facecolor='White', bbox_inches='tight')
plt.show()

# %%
# plot skewness of dA distribution
fig, ax = plt.subplots(1, 1, figsize=(5, 4))

ax.hist(results_res_abs['dA_skew'], bins=20, range=(-1, 3.5), histtype='step', density=True, label=f'$|m - m_h|$')
ax.hist(results_res_chi2['dA_skew'], bins=20, range=(-1, 3.5), histtype='step', density=True, label=f'$(m - m_h)^2$')
ax.hist(results_res_SPANet['dA_skew'], bins=20, range=(-1, 3.5), histtype='step', density=True, label=f'SPANet')
ax.hist(results_res_truth['dA_skew'], bins=20, range=(-1, 3.5), histtype='step', density=True, label=f'Truth')

ax.legend(frameon=False, loc='upper right')
ax.set_xlabel('Skewness of $\Delta A$')
ax.set_ylabel('Normalized counts')
ax.set_title('Skewness of $\Delta A$ distribution')

# plt.savefig('../figures/dA_skew_distribution-abs_pairing.pdf', dpi=300, facecolor='White', bbox_inches='tight')
plt.show()

# plot skewness of dA distribution
fig, ax = plt.subplots(1, 1, figsize=(5, 4))

ax.hist(results_6b_abs['dA_skew'], bins=20, range=(-1, 3.5), histtype='step', density=True, label=f'$|m - m_h|$')
ax.hist(results_6b_chi2['dA_skew'], bins=20, range=(-1, 3.5), histtype='step', density=True, label=f'$(m - m_h)^2$')
ax.hist(results_6b_SPANet['dA_skew'], bins=20, range=(-1, 3.5), histtype='step', density=True, label=f'SPANet')

ax.legend(frameon=False, loc='upper right')
ax.set_xlabel('Skewness of $\Delta A$')
ax.set_ylabel('Normalized counts')
ax.set_title('Skewness of $\Delta A$ distribution')

# plt.savefig('../figures/dA_skew_distribution-abs_pairing.pdf', dpi=300, facecolor='White', bbox_inches='tight')
plt.show()

# %%
# plot HT distribution
fig, ax = plt.subplots(1, 1, figsize=(5, 4))

ax.hist(results_res_abs['HT'], bins=20, range=(200, 1600), histtype='step', density=True, label=f'$|m - m_h|$')
ax.hist(results_res_chi2['HT'], bins=20, range=(200, 1600), histtype='step', density=True, label=f'$(m - m_h)^2$')
ax.hist(results_res_SPANet['HT'], bins=20, range=(200, 1600), histtype='step', density=True, label=f'SPANet')
ax.hist(results_res_truth['HT'], bins=20, range=(200, 1600), histtype='step', density=True, label=f'Truth')

ax.legend(frameon=False, loc='upper right')
ax.set_xlabel('$H_{T, \mathrm{6jets}}$ (GeV)')
ax.set_ylabel('Normalized counts')
ax.set_title('$H_T$ distribution')

# plt.savefig('../figures/HT_distribution-abs_pairing.pdf', dpi=300, facecolor='White', bbox_inches='tight')
plt.show()

# plot HT distribution
fig, ax = plt.subplots(1, 1, figsize=(5, 4))

ax.hist(results_6b_abs['HT'], bins=20, range=(200, 1600), histtype='step', density=True, label=f'$|m - m_h|$')
ax.hist(results_6b_chi2['HT'], bins=20, range=(200, 1600), histtype='step', density=True, label=f'$(m - m_h)^2$')
ax.hist(results_6b_SPANet['HT'], bins=20, range=(200, 1600), histtype='step', density=True, label=f'SPANet')

ax.legend(frameon=False, loc='upper right')
ax.set_xlabel('$H_{T, \mathrm{6jets}}$ (GeV)')
ax.set_ylabel('Normalized counts')
ax.set_title('$H_T$ distribution')

# plt.savefig('../figures/HT_distribution-abs_pairing.pdf', dpi=300, facecolor='White', bbox_inches='tight')
plt.show()

# %%
# plot mhCostheta distribution
fig, ax = plt.subplots(1, 1, figsize=(5, 4))

ax.hist(results_res_abs['mhCostheta'], bins=20, range=(-1.0, 1.0), histtype='step', density=True, label=f'$|m - m_h|$')
ax.hist(results_res_chi2['mhCostheta'], bins=20, range=(-1.0, 1.0), histtype='step', density=True, label=f'$(m - m_h)^2$')
ax.hist(results_res_SPANet['mhCostheta'], bins=20, range=(-1.0, 1.0), histtype='step', density=True, label=f'SPANet')
ax.hist(results_res_truth['mhCostheta'], bins=20, range=(-1.0, 1.0), histtype='step', density=True, label=f'Truth')

ax.legend(frameon=False, loc='upper right')
ax.set_xlabel('$m_h\cos\\theta$')
ax.set_ylabel('Normalized counts')
ax.set_title('$m_h\cos\\theta$ distribution')

plt.savefig('../figures/mhCostheta_distribution_signal.pdf', dpi=300, facecolor='White', bbox_inches='tight')
plt.show()

# plot mhCostheta distribution
fig, ax = plt.subplots(1, 1, figsize=(5, 4))

ax.hist(results_6b_abs['mhCostheta'], bins=20, range=(-1.0, 1.0), histtype='step', density=True, label=f'$|m - m_h|$')
ax.hist(results_6b_chi2['mhCostheta'], bins=20, range=(-1.0, 1.0), histtype='step', density=True, label=f'$(m - m_h)^2$')
ax.hist(results_6b_SPANet['mhCostheta'], bins=20, range=(-1.0, 1.0), histtype='step', density=True, label=f'SPANet')

ax.legend(frameon=False, loc='upper left')
ax.set_xlabel('$m_h\cos\\theta$')
ax.set_ylabel('Normalized counts')
ax.set_title('$m_h\cos\\theta$ distribution')

plt.savefig('../figures/mhCostheta_distribution_background.pdf', dpi=300, facecolor='White', bbox_inches='tight')
plt.show()

# %%
# plot eta-mhhh distribution
fig, ax = plt.subplots(1, 1, figsize=(5, 4))

ax.hist(results_res_abs['eta_mhhh_fraction'], bins=20, range=(0, 1), histtype='step', density=True, label=f'$|m - m_h|$')
ax.hist(results_res_chi2['eta_mhhh_fraction'], bins=20, range=(0, 1), histtype='step', density=True, label=f'$(m - m_h)^2$')
ax.hist(results_res_SPANet['eta_mhhh_fraction'], bins=20, range=(0, 1), histtype='step', density=True, label=f'SPANet')
ax.hist(results_res_truth['eta_mhhh_fraction'], bins=20, range=(0, 1), histtype='step', density=True, label=f'Truth')

ax.legend(frameon=False, loc='upper right')
ax.set_xlabel('$\eta - m_{hhh}$ fraction')
ax.set_ylabel('Normalized counts')
ax.set_title('$\eta - m_{hhh}$ fraction distribution')

# plt.savefig('../figures/eta_mhhh_fraction_distribution-abs_pairing.pdf', dpi=300, facecolor='White', bbox_inches='tight')
plt.show()

# plot eta-mhhh distribution
fig, ax = plt.subplots(1, 1, figsize=(5, 4))

ax.hist(results_6b_abs['eta_mhhh_fraction'], bins=20, range=(0, 1), histtype='step', density=True, label=f'$|m - m_h|$')
ax.hist(results_6b_chi2['eta_mhhh_fraction'], bins=20, range=(0, 1), histtype='step', density=True, label=f'$(m - m_h)^2$')
ax.hist(results_6b_SPANet['eta_mhhh_fraction'], bins=20, range=(0, 1), histtype='step', density=True, label=f'SPANet')

ax.legend(frameon=False, loc='upper left')
ax.set_xlabel('$\eta - m_{hhh}$ fraction')
ax.set_ylabel('Normalized counts')
ax.set_title('$\eta - m_{hhh}$ fraction distribution')

# plt.savefig('../figures/eta_mhhh_fraction_distribution-abs_pairing.pdf', dpi=300, facecolor='White', bbox_inches='tight')
plt.show()

# %%
# plot sphericity distribution
fig, ax = plt.subplots(1, 1, figsize=(5, 4))

ax.hist(results_res_abs['sphericity'], bins=20, histtype='step', density=True, label=f'$|m - m_h|$')
ax.hist(results_res_chi2['sphericity'], bins=20, histtype='step', density=True, label=f'$(m - m_h)^2$')
ax.hist(results_res_SPANet['sphericity'], bins=20, histtype='step', density=True, label=f'SPANet')
ax.hist(results_res_truth['sphericity'], bins=20, histtype='step', density=True, label=f'Truth')

ax.legend(frameon=False, loc='upper right')
ax.set_xlabel('Sphericity')
ax.set_ylabel('Normalized counts')
ax.set_title('Sphericity distribution')

# plt.savefig('../figures/sphericity_distribution-abs_pairing.pdf', dpi=300, facecolor='White', bbox_inches='tight')
plt.show()

# plot sphericity distribution
fig, ax = plt.subplots(1, 1, figsize=(5, 4))

ax.hist(results_6b_abs['sphericity'], bins=20, histtype='step', density=True, label=f'$|m - m_h|$')
ax.hist(results_6b_chi2['sphericity'], bins=20, histtype='step', density=True, label=f'$(m - m_h)^2$')
ax.hist(results_6b_SPANet['sphericity'], bins=20, histtype='step', density=True, label=f'SPANet')

ax.legend(frameon=False, loc='upper right')
ax.set_xlabel('Sphericity')
ax.set_ylabel('Normalized counts')
ax.set_title('Sphericity distribution')

# plt.savefig('../figures/sphericity_distribution-abs_pairing.pdf', dpi=300, facecolor='White', bbox_inches='tight')
plt.show()

# %%
# plot aplanarity distribution
fig, ax = plt.subplots(1, 1, figsize=(5, 4))

ax.hist(results_res_abs['aplanarity'], bins=20, range=(0, 0.4), histtype='step', density=True, label=f'$|m - m_h|$')
ax.hist(results_res_chi2['aplanarity'], bins=20, range=(0, 0.4), histtype='step', density=True, label=f'$(m - m_h)^2$')
ax.hist(results_res_SPANet['aplanarity'], bins=20, range=(0, 0.4), histtype='step', density=True, label=f'SPANet')
ax.hist(results_res_truth['aplanarity'], bins=20, range=(0, 0.4), histtype='step', density=True, label=f'Truth')

ax.legend(frameon=False, loc='upper right')
ax.set_xlabel('Aplanarity')
ax.set_ylabel('Normalized counts')
ax.set_title('Aplanarity distribution')

# plt.savefig('../figures/aplanarity_distribution-abs_pairing.pdf', dpi=300, facecolor='White', bbox_inches='tight')
plt.show()

# plot aplanarity distribution
fig, ax = plt.subplots(1, 1, figsize=(5, 4))

ax.hist(results_6b_abs['aplanarity'], bins=20, range=(0, 0.4), histtype='step', density=True, label=f'$|m - m_h|$')
ax.hist(results_6b_chi2['aplanarity'], bins=20, range=(0, 0.4), histtype='step', density=True, label=f'$(m - m_h)^2$')
ax.hist(results_6b_SPANet['aplanarity'], bins=20, range=(0, 0.4), histtype='step', density=True, label=f'SPANet')

ax.legend(frameon=False, loc='upper right')
ax.set_xlabel('Aplanarity')
ax.set_ylabel('Normalized counts')
ax.set_title('Aplanarity distribution')

# plt.savefig('../figures/aplanarity_distribution-abs_pairing.pdf', dpi=300, facecolor='White', bbox_inches='tight')
plt.show()
